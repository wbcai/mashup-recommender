# %%
import bpm_harm
import pandas as pd 
import numpy as np 
from os import path
import os
import sys
import networkx as nx

# %%
metadf = pd.read_csv('/Users/briancai/Drive/NU/DJ_recommender/mashup-recommender/data/librosa_spotipy_output.csv')

# %%
metadf.head()
# Out:
#                               track      bpm         C        Db         D  \
# 0  Kanye West - Flashing Lights.mp3   90.482  0.036954  0.139994  0.115554
# 1       Disclosure - Holding On.mp3  124.004  0.104696  0.050207  0.119832
# 2            Disclosure - Latch.mp3  121.986  0.143480  0.060934  0.025518
# 3               Four Tet - Baby.mp3  127.066  0.140537  0.026422  0.183901
# 4      Kodak Black - Patty Cake.mp3  152.094  0.023424  0.101666  0.050954
#
#          Eb         E         F        Gb         G        Ab         A  \
# 0  0.031186  0.039300  0.026493  0.160133  0.062567  0.084075  0.111546
# 1  0.012404  0.040165  0.318739  0.008048  0.036769  0.034997  0.131350
# 2  0.150654  0.028151  0.116328  0.020705  0.027879  0.176081  0.060752
# 3  0.066187  0.034937  0.138957  0.007637  0.100334  0.052317  0.175298
# 4  0.067617  0.181116  0.059285  0.122313  0.037431  0.151896  0.026322
#
#          Bb         B      result_name  key  mode  instrumentalness  \
# 0  0.043015  0.149184  Flashing Lights    6     0          0.000000
# 1  0.090003  0.052791       Holding On    5     1          0.000246
# 2  0.133491  0.056030            Latch    1     1          0.000193
# 3  0.021419  0.052054             Baby    0     1          0.003250
# 4  0.014489  0.163487       Patty Cake    1     0          0.000000
#
#    speechiness  join
# 0       0.0399     1
# 1       0.3330     1
# 2       0.0919     1
# 3       0.2480     1
# 4       0.1900     1

# %%
metadf.Db.plot.hist()

# %%
metadf['track'] = metadf.track.str.replace('.mp3','')
metadf['track'] = metadf.track.str.replace('.wav','')
metadf['track'] = metadf.track.str.split(' - ').str[1]

# %%
metadf.head()
# Out:
#              track      bpm         C        Db         D        Eb         E  \
# 0  Flashing Lights   90.482  0.036954  0.139994  0.115554  0.031186  0.039300
# 1       Holding On  124.004  0.104696  0.050207  0.119832  0.012404  0.040165
# 2            Latch  121.986  0.143480  0.060934  0.025518  0.150654  0.028151
# 3             Baby  127.066  0.140537  0.026422  0.183901  0.066187  0.034937
# 4       Patty Cake  152.094  0.023424  0.101666  0.050954  0.067617  0.181116
#
#           F        Gb         G        Ab         A        Bb         B  \
# 0  0.026493  0.160133  0.062567  0.084075  0.111546  0.043015  0.149184
# 1  0.318739  0.008048  0.036769  0.034997  0.131350  0.090003  0.052791
# 2  0.116328  0.020705  0.027879  0.176081  0.060752  0.133491  0.056030
# 3  0.138957  0.007637  0.100334  0.052317  0.175298  0.021419  0.052054
# 4  0.059285  0.122313  0.037431  0.151896  0.026322  0.014489  0.163487
#
#        result_name  key  mode  instrumentalness  speechiness  join
# 0  Flashing Lights    6     0          0.000000       0.0399     1
# 1       Holding On    5     1          0.000246       0.3330     1
# 2            Latch    1     1          0.000193       0.0919     1
# 3             Baby    0     1          0.003250       0.2480     1
# 4       Patty Cake    1     0          0.000000       0.1900     1

# %%
distances = pd.read_csv('/Users/briancai/Drive/NU/DJ_recommender/mashup-recommender/data/distances.csv', index_col = 0)

# %%
distances.loc[distances.track_x.str.startswith("Kendrick"), ['track_x']] = "Kendrick Lamar - HUMBLE (Skrillex Remix).mp3"
distances.loc[distances.track_y.str.startswith("Kendrick"), ['track_y']] = "Kendrick Lamar - HUMBLE (Skrillex Remix).mp3"

# %%
distances_unique = distances.loc[[i for i in range(0, len(distances), 2)]].reset_index(drop = True)

# %%
top5p = distances_unique.loc[[i for i in range(0, 523)]]

# %%
top5p['track_x'] = top5p.track_x.str.replace('.mp3', '')
top5p['track_y'] = top5p.track_y.str.replace('.mp3', '')
top5p['track_x'] = top5p.track_x.str.replace('.wav', '')
top5p['track_y'] = top5p.track_y.str.replace('.wav', '')
top5p['track_x'] = top5p.track_x.str.split(' - ').str[1]
top5p['track_y'] = top5p.track_y.str.split(' - ').str[1]

# %%
tracklist = top5p.track_x.tolist()
tracklist.extend(top5p.track_y.tolist())
tracklist = list(set(tracklist))

# %%
metadf.loc[metadf.track.isna(),:]
# Out:
# Empty DataFrame
# Columns: [track, bpm, C, Db, D, Eb, E, F, Gb, G, Ab, A, Bb, B, result_name, key, mode, instrumentalness, speechiness, join]
# Index: []

# %%
tracklist
# Out:
# ['Mind (Malaa remix)',
#  'Baby',
#  'Work (DJZA Tech House Remix)',
#  'SICKO MODE',
#  'Single Ladies (Put a Ring on It)',
#  'Get It Together',
#  'No Return',
#  'Missing You',
#  'Underwater (Adam Port Remix)',
#  'Low Key Goddess',
#  'Tell Me',
#  'The Next Episode',
#  'HUMBLE (Skrillex Remix)',
#  'Crazy In Love',
#  'Nice For What',
#  'Rhymes',
#  'Masta Blasta (THE REBIRTH)',
#  'Holding On',
#  'Something New',
#  'You & Me',
#  'Father Stretch My Hands Pt. 1',
#  'Veins',
#  'This Is America (remix)',
#  'Memories That You Call (ODESZA & Golden Features VIP Remix)',
#  'Cream',
#  'Pursuit of Happiness',
#  'Loyal',
#  'Just',
#  'SPEEDBOAT',
#  'Flashing Lights',
#  'Aerodynamic',
#  'Notorious',
#  'Snowchild',
#  'CP-1',
#  'Mi Gente',
#  'Face My Fears.m4a',
#  'Genesis',
#  'Midnight City (Eric Prydz Remix)',
#  'Better Off Alone',
#  'I Want You',
#  'Going Bad',
#  "EDM O'CLOCK",
#  'Okay',
#  'Faded',
#  'Sexual Healing (Kygo Remix)',
#  'Prophecy',
#  'Pony',
#  'Estamos Bien',
#  'Poison (RIFFA Bootleg)',
#  "Drop It LIke It's Hot (DEL30 remix)",
#  'Ghost Voices (Lane 8 Remix)',
#  'Only Human',
#  'Brighter',
#  'Passionfruit',
#  'Never Be Like You (Disclosure Remix)',
#  'Losing It',
#  'Planet',
#  'Exhale',
#  'The Difference',
#  'On Sight',
#  "Everybody (Backstreet's Back)",
#  'Stimulation',
#  'In The End',
#  'Bloom (Lane 8 Remix)',
#  'One More Time (Capital People Remix)',
#  'When A Fire Starts To Burn',
#  'goosebumps.m4a',
#  'Limit To Your Love (Club remix)',
#  'Hold Tight',
#  'Body Funk (Dom Dolla Remix)',
#  'Yummy (Dance remix)',
#  'Unfaith',
#  'Hellifornia',
#  'Fade',
#  'Zoom Zoom',
#  'Bambro Koyo Ganda',
#  'My Life (Kyle Watson Remix)',
#  'Latch',
#  '5200',
#  'Kiss It Better (Four Tet Remix)',
#  'Drunk in Love',
#  'Mumbai Power',
#  'Harder, Better, Faster, Stronger',
#  'Tight',
#  "Holdin' On",
#  "Can't Do Without You (Tale Of Us Remix)",
#  'Fly Kicks (Wax Motif Remix)',
#  'Need You',
#  'Rhythm Of The Night (Blonde Remix)',
#  '0 To 100',
#  'Y.O.D.O',
#  'Omen (Jonas Rathsman Remix)',
#  'Wake',
#  "I'm Sprung",
#  'BREAK LAW',
#  'Say My Name (feat. Zyra)',
#  'Rotlicht',
#  'Formation',
#  'Play That Funky Music (Gordo Edit)',
#  'TURN OFF THE LIGHTS',
#  'Easy.m4a',
#  'Midnight Hour',
#  'Goh (AC Slater Remix)',
#  'I Want It That Way',
#  'Pay For What',
#  'Cry Me a River',
#  'You Are Going to Love Me and Scream',
#  "Don't Go (Dusky Remix)",
#  'Show Me Show Me',
#  'SeeSaw (Club Version)',
#  'raingurl',
#  'Everything I Wanted (Rauschhaus Edit)',
#  'D.A.N.C.E',
#  'Get Low',
#  'I Like It (Dillon Francis Remix)',
#  'Strangers',
#  'You Little Beauty',
#  'Pressure (Valentino Khan Remix)',
#  'Tides (Dixon Remix)',
#  'Patty Cake',
#  'Runaway (U&I)',
#  'Burns']

# %%
nodes = metadf.loc[metadf.track.isin(tracklist), ['track', 'track', 'bpm']]

nodes.columns = ['Id', 'Label', 'BPM']

# %%
edges = top5p.loc[:, ['track_x', 'track_y', 'dist']]

edges.columns = ['Source', 'Target', 'Weight']

edges['Type'] = 'Undirected'

# %%
nodes.head()
# Out:
#                 Id            Label      BPM
# 0  Flashing Lights  Flashing Lights   90.482
# 1       Holding On       Holding On  124.004
# 2            Latch            Latch  121.986
# 3             Baby             Baby  127.066
# 4       Patty Cake       Patty Cake  152.094

# %%
edges.head(30)
# Out:
#                                      Source  \
# 0                     Goh (AC Slater Remix)
# 1                                 D.A.N.C.E
# 2                                  Mi Gente
# 3          Harder, Better, Faster, Stronger
# 4           Pressure (Valentino Khan Remix)
# 5               Omen (Jonas Rathsman Remix)
# 6                               EDM O'CLOCK
# 7                                      Baby
# 8                   HUMBLE (Skrillex Remix)
# 9                                      Baby
# 10                                 Prophecy
# 11            Everybody (Backstreet's Back)
# 12                                SPEEDBOAT
# 13                          Get It Together
# 14                                     Just
# 15                       I Want It That Way
# 16       Play That Funky Music (Gordo Edit)
# 17          Pressure (Valentino Khan Remix)
# 18                     Pursuit of Happiness
# 19  Can't Do Without You (Tale Of Us Remix)
# 20                                   Rhymes
# 21                              Missing You
# 22                          Flashing Lights
# 23                              Missing You
# 24                                D.A.N.C.E
# 25                           goosebumps.m4a
# 26               When A Fire Starts To Burn
# 27         I Like It (Dillon Francis Remix)
# 28                   Poison (RIFFA Bootleg)
# 29                                 0 To 100
#
#                                 Target    Weight        Type
# 0           When A Fire Starts To Burn  0.007910  Undirected
# 1                   I Want It That Way  0.009291  Undirected
# 2                             Need You  0.009652  Undirected
# 3                            D.A.N.C.E  0.011668  Undirected
# 4   Play That Funky Music (Gordo Edit)  0.012141  Undirected
# 5                                Cream  0.012202  Undirected
# 6                            Formation  0.012491  Undirected
# 7                               Planet  0.012651  Undirected
# 8                           SICKO MODE  0.013040  Undirected
# 9                        Midnight Hour  0.013190  Undirected
# 10                               Loyal  0.013376  Undirected
# 11                   You Little Beauty  0.013734  Undirected
# 12                          Only Human  0.014062  Undirected
# 13                           Strangers  0.014108  Undirected
# 14                              Planet  0.014249  Undirected
# 15                       Something New  0.014975  Undirected
# 16                          I Want You  0.014986  Undirected
# 17                       Midnight Hour  0.014996  Undirected
# 18               SeeSaw (Club Version)  0.015054  Undirected
# 19                Pursuit of Happiness  0.015167  Undirected
# 20                          Holding On  0.015283  Undirected
# 21               Goh (AC Slater Remix)  0.015497  Undirected
# 22                  I Want It That Way  0.016009  Undirected
# 23          When A Fire Starts To Burn  0.016172  Undirected
# 24  Play That Funky Music (Gordo Edit)  0.016599  Undirected
# 25                 TURN OFF THE LIGHTS  0.016739  Undirected
# 26                 TURN OFF THE LIGHTS  0.016873  Undirected
# 27                       Drunk in Love  0.016950  Undirected
# 28               Goh (AC Slater Remix)  0.017427  Undirected
# 29                           Going Bad  0.017464  Undirected

# %%
edge_list = [(top5p.loc[i, 'track_x'],
             top5p.loc[i, 'track_y'],
             {'dist':top5p.loc[i, 'dist']}) for i in range(0,len(top5p))]

# %%
G = nx.Graph()

# %%
G.add_weighted_edges_from(edge_list)

# %%
G.number_of_nodes()
# Out:
# 122

# %%
G.number_of_edges()
# Out:
# 523

# %%
eigen_centr = nx.eigenvector_centrality_numpy(G, weight='dist', max_iter=50, tol=0)

# %%
eigen_cent_df = pd.DataFrame(eigen_centr, columns = ['track', 'eigenvector_centrality'])

# %%
type(eigen_centr)
# Out:
# dict

# %%
nodes['eigenvector_centrality'] = nodes.Id.map(eigen_centr)

# %%
nodes.sort_values(by = 'eigenvector_centrality', ascending = False)
# Out:
#                                   Id                            Label  \
# 14        When A Fire Starts To Burn       When A Fire Starts To Burn
# 135                      Missing You                      Missing You
# 93             Goh (AC Slater Remix)            Goh (AC Slater Remix)
# 133              TURN OFF THE LIGHTS              TURN OFF THE LIGHTS
# 115  Pressure (Valentino Khan Remix)  Pressure (Valentino Khan Remix)
# ..                               ...                              ...
# 23                         Going Bad                        Going Bad
# 44       Sexual Healing (Kygo Remix)      Sexual Healing (Kygo Remix)
# 83                        I'm Sprung                       I'm Sprung
# 128                  Show Me Show Me                  Show Me Show Me
# 19                         Losing It                        Losing It
#
#             BPM  eigenvector_centrality
# 14   123.948000            2.708301e-01
# 135  126.996000            2.608357e-01
# 93   129.199219            2.456306e-01
# 133  128.027000            2.419311e-01
# 115  126.012000            2.390382e-01
# ..          ...                     ...
# 23    86.003000            1.732197e-05
# 44   100.987000            1.144185e-05
# 83    99.991000            7.011984e-07
# 128  122.995000            1.688981e-17
# 19   125.000000           -1.620167e-17
#
# [122 rows x 4 columns]

# %%
edges.to_csv("/Users/briancai/Drive/NU/DJ_recommender/mashup-recommender/data/edges.csv", index = False)
nodes.to_csv("/Users/briancai/Drive/NU/DJ_recommender/mashup-recommender/data/nodes.csv", index = False)
